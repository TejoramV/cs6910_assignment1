# %% [markdown]
# # CS6910 Assignment-1

# %% [markdown]
# by
# - Akansh Maurya (CS22Z003)
# - Tejoram Vivekanandan (EE22Z001)

# %%
from keras.datasets import fashion_mnist
import numpy as np
from  matplotlib import pyplot as plt
import time
import math
from sklearn.model_selection import train_test_split
from tqdm.auto import tqdm

# %% [markdown]
# ### Question 1: Loading and ploting the dataset

# %%
dataset= fashion_mnist.load_data()
(X_train_and_validation, y_train_and_validation), (X_test, y_test) = dataset
X_train, X_validation, y_train, y_validation = train_test_split(X_train_and_validation, y_train_and_validation, test_size=0.1, random_state=42)
X_train = (X_train/255.0).astype(np.float32)
X_validation = (X_validation/255.0).astype(np.float32)
X_test = (X_test/255.0).astype(np.float32)

print("Train Dataset Shape: ", X_train.shape)
print("Train Target Vector Shape: ", y_train.shape) 
print("Test Dataset Shape:", X_test.shape)
print("Test Target Vector Shape", y_test.shape)
print("Validation Dataset Shape:", X_validation.shape)
print("Validation Target Vector Shape", y_validation.shape)
# Out:
# Train Dataset Shape:  (54000, 28, 28)
# Train Target Vector Shape:  (54000,)
# Test Dataset Shape: (10000, 28, 28)
# Test Target Vector Shape (10000,)
# Validation Dataset Shape: (6000, 28, 28)
# Validation Target Vector Shape (6000,)

# %%
X_train = np.array(X_train.reshape(X_train.shape[0], 784,1))         
X_test = np.array(X_test.reshape(X_test.shape[0], 784,1))
X_validation = np.array(X_validation.reshape(X_validation.shape[0], 784,1))

# %% [markdown]
# **Implement a feedforward and backpropagation**

# %%
#Activation function
def activation(activation_function):
  if activation_function == 'sigmoid':
    return sigmoid
  if activation_function == 'tanh':
    return tanh
  if activation_function == 'ReLU':
    return relu

def sigmoid(x, derivative = False):
  if derivative:
    return sigmoid(x)*(1-sigmoid(x))
  return 1/(1 + np.exp(-x))  

def tanh(x, derivative = False):
  if derivative:
    return 1 - tanh(x)**2
  return (np.exp(x)-np.exp(-x))/(np.exp(x)+np.exp(-x))

def relu(x, derivative = False):
  if derivative:
    return (x>0)*1 
  return x*(x>0)

def softmax(x,derivative = False):
  if derivative:
    return softmax(x)*(1- softmax(x))
  return np.exp(x)/np.sum(np.exp(x), axis = 0)

def one_hot(y, num_output_nodes):
  v = np.zeros((num_output_nodes, len(y)))
  for i,j in enumerate(y):
    v[j,i] = 1
  return v

### Weight Initialization
def param_inint(num_inputs_nodes, hidden_layers, num_output_nodes, init_type):
  W = []
  B = []
  if init_type == "random":
    W.append(np.random.randn(hidden_layers[0],num_inputs_nodes)*0.1)
    B.append(np.random.randn(hidden_layers[0], 1)*0.1)
    for i in range(len(hidden_layers)-1):
      W.append(np.random.randn(hidden_layers[i+1],hidden_layers[i])*0.1)
      B.append(np.random.randn(hidden_layers[i+1], 1)*0.1)
    W.append(np.random.randn(num_output_nodes, hidden_layers[-1])*0.1)
    B.append(np.random.randn(num_output_nodes, 1)*0.1)
    return W, B

  if init_type == "xavier":
    W.append(np.random.randn(hidden_layers[0],num_inputs_nodes)*np.sqrt(2/(hidden_layers[0] + num_inputs_nodes)))
    B.append(np.random.randn(hidden_layers[0], 1)*0.1)
    for i in range(len(hidden_layers)-1):
      W.append(np.random.randn(hidden_layers[i+1],hidden_layers[i])*np.sqrt(2/(hidden_layers[i+1] + hidden_layers[i])))
      B.append(np.random.randn(hidden_layers[i+1], 1)*0.1)
    W.append(np.random.randn(num_output_nodes, hidden_layers[-1])*np.sqrt(2/(num_output_nodes + hidden_layers[-1])))
    B.append(np.random.randn(num_output_nodes, 1)*0.1)
    return W, B


def feed_forward(x, W, B, activation_type):
  h = []
  a = []
  sigma = activation(activation_type)  #activation
  h.append(x)   #h0 = x
  a.append(np.dot(W[0], h[0]) + B[0])
  for i in range(len(W)-1):
    h.append(sigma(a[-1]))
    a.append(np.dot(W[i+1], h[-1]) + B[i+1])
  y_hat = softmax(a[-1])

  return y_hat, h, a



def loss_compute(y,y_hat, loss_type, W, reg_lamda):
  if loss_type == "squared_error":
    error = np.sum((one_hot(y, 10)-y_hat)**2)/(2*one_hot(y, 10).shape[1])
  if loss_type == "cross_entropy":
    error = -1*np.sum(np.multiply(one_hot(y, 10),np.log(y_hat)))/one_hot(y, 10).shape[1]         # hardcoded classes = 10

  if W:
    r = 0
    for i in range(len(W)):
      r += np.sum((np.array(W, dtype = object) **2)[i])
    error = error + reg_lamda * r

  return error


def accuracy(y_hat, y_true):
  return np.mean(np.argmax(y_hat, axis = 0) ==y_true )*100

# %% [markdown]
# ##### Back Propogation

# %%
def back_prop(x, y, y_hat, a, h , W, B, batch_size, loss_type, activation_type):
  gh = [0]*len(h)
  ga = [0]*len(a)
  gw = [0]*len(W)
  gb = [0]*len(B)

  sigma = activation(activation_type) 

  if loss_type == "cross_entropy":
    gh[-1] = -1*(y/y_hat)
    ga[-1] = -1*(y-y_hat)
  if loss_type == "squared_error":   ##### edit this
    gh[-1] = y_hat - y
    ga[-1] = (y_hat - y)*softmax(a[-1])*(1-softmax(a[-1]))

  for i in range(len(W)-1, -1, -1):
    gw[i] = np.dot(ga[i], h[i].T)
    gb[i] = np.dot(ga[i], np.ones((batch_size,1)))
    if i > 0:
      gh[i-1] = np.dot(W[i].T, ga[i])
      ga[i-1]  = np.multiply(gh[i-1],sigma(a[i-1], derivative = True))

  return gw, gb, gh, ga

# %% [markdown]
# **Optimizing functions**

# %%
class SGD:
  ''' Stochastic Gradient Descent '''
  def __init__(self, lr = 0.001, reg = 0):
    self.lr = lr
    self.reg = reg
  
  def update(self, w,b, gW, gB):
    W = np.array(w, dtype = object)
    B = np.array(b, dtype = object)

    W = (1-self.lr*self.reg)*W - self.lr * np.array(gW, dtype = object)
    B = (1-self.lr*self.reg)*B - self.lr * np.array(gB, dtype = object)

    return W.tolist(),B.tolist()


class Momentum:

  def __init__(self, lr = 0.001, gamma = 0.9, reg = 0):
    self.lr = lr
    self.gamma = gamma
    self.Wmoments = None
    self.Bmoments = None
    self.reg = reg


  def update(self, w,b, gW, gB):
    params = {'w':w, 'b':b}

    if self.Wmoments == None:
      self.Wmoments = [0] * len(params['w'])
      for i in range(len(params['w'])):
        self.Wmoments[i] = np.zeros_like(params['w'][i])

    if self.Bmoments == None:
      self.Bmoments = [0] * len(params['b'])
      for i in range(len(params['b'])):
        self.Bmoments[i] = np.zeros_like(params['b'][i])
    
    self.Wmoments = self.gamma * np.array(self.Wmoments, dtype = object) + self.lr * np.array(gW, dtype = object)
    W = (1-self.lr*self.reg)*np.array(params['w'], dtype = object) - self.Wmoments
    self.Wmoments = self.Wmoments.tolist()

    self.Bmoments = self.gamma * np.array(self.Bmoments, dtype = object) + self.lr * np.array(gB, dtype = object)
    B = (1-self.lr*self.reg)*np.array(params['b'], dtype = object) - self.Bmoments
    self.Bmoments = self.Bmoments.tolist()
    
    return W.tolist(), B.tolist()


class RMSprop:
  def __init__(self, lr=0.01, beta = 0.99):
    
    self.lr = lr
    self.vW = None
    self.vB = None
    self.beta = beta

  def update(self, w,b, gW, gB):
    params = {'w':w, 'b':b}
    if self.vW == None:
      self.vW = [0] * len(params['w'])
      for i in range(len(params['w'])):
        self.vW[i] = np.zeros_like(params['w'][i])

    if self.vB == None:
      self.vB = [0] * len(params['b'])
      for i in range(len(params['b'])):
        self.vB[i] = np.zeros_like(params['b'][i])

    self.vW = self.beta*np.array(self.vW, dtype = object) + (1-self.beta)*(np.array(gW, dtype = object) **2) 
    W = (1-self.lr*self.reg)*np.array(params['w'], dtype = object) - (self.lr/((self.vW + 1e-7)**0.5)) * np.array(gW, dtype = object)
    self.vW = self.vW.tolist()

    self.vB = self.beta*np.array(self.vB, dtype = object) + (1-self.beta)*(np.array(gB, dtype = object) **2 )
    B = (1-self.lr*self.reg)*np.array(params['b'], dtype = object) - (self.lr/((self.vB + 1e-7)**0.5)) * np.array(gB, dtype = object)
    self.vB = self.vB.tolist()

    return W.tolist(), B.tolist()

class Nesterov:   
  def __init__(self, lr=0.01, gamma=0.9):
    self.lr = lr
    self.reg = None
    self.gamma = gamma                                                             
    self.Wmoments = None
    self.Bmoments = None
    self.activation_type = None
    self.loss_type = None
        
  def update(self, w,b, gW, gB):
    params = {'w':w, 'b':b}
    if self.Wmoments == None:
      self.Wmoments = [0] * len(params['w'])
      for i in range(len(params['w'])):
        self.Wmoments[i] = np.zeros_like(params['w'][i])

    if self.Bmoments == None:
      self.Bmoments = [0] * len(params['b'])
      for i in range(len(params['b'])):
        self.Bmoments[i] = np.zeros_like(params['b'][i])


    W_look_ahead = np.array(params['w'], dtype = object) - self.gamma*np.array(self.Wmoments, dtype = object)
    B_look_ahead = np.array(params['b'], dtype = object) - self.gamma*np.array(self.Bmoments, dtype = object)
    ##
    out, temp_h, temp_a = feed_forward(x,W_look_ahead.tolist(),B_look_ahead.tolist(), self.activation_type)
    gW_look_ahead, gB_look_ahead, _, _ = back_prop(x, y,out,temp_a,temp_h, W_look_ahead.tolist(),B_look_ahead.tolist(), x.shape[1], self.loss_type, self.activation_type)

    ###
    self.Wmoments = self.gamma*np.array(self.Wmoments, dtype = object) + self.lr * np.array(gW_look_ahead, dtype = object)
    self.Bmoments = self.gamma*np.array(self.Bmoments, dtype = object) + self.lr * np.array(gB_look_ahead, dtype = object)

    W = (1-self.lr*self.reg)*np.array(params['w'], dtype = object) - self.Wmoments
    self.Wmoments = self.Wmoments.tolist()

    B = (1-self.lr*self.reg)*np.array(params['b'], dtype = object) - self.Bmoments
    self.Bmoments = self.Bmoments.tolist()

    return W.tolist(), B.tolist()

class Adam:
  def __init__(self, lr=0.001, beta1=0.9, beta2=0.999, reg = 0):
    self.lr = lr
    self.beta1 = beta1
    self.beta2 = beta2
    self.t = 0
    self.mW = None
    self.vW = None
    self.mB = None
    self.vB = None
    self.reg = None
        
  def update(self, w,b, gW, gB):
    params = {'w':w, 'b':b}

    if self.mW is None:
      self.mW, self.vW = [0] * len(params['w']), [0] * len(params['w'])
      for i in range(len(params['w'])):
        self.mW[i] = np.zeros_like(params['w'][i])
        self.vW[i] = np.zeros_like(params['w'][i])

    if self.mB is None:
      self.mB, self.vB = [0] * len(params['b']), [0] * len(params['b'])
      for i in range(len(params['b'])):
        self.mB[i] = np.zeros_like(params['b'][i])
        self.vB[i] = np.zeros_like(params['b'][i])
    

    self.t += 1
    self.mW = (self.beta1 * np.array(self.mW, dtype = object)) + (1-self.beta1)*(np.array(gW, dtype = object))
    self.vW = (self.beta2 * np.array(self.vW, dtype = object)) + (1-self.beta2)*((np.array(gW, dtype = object)**2))

    self.mB = (self.beta1 * np.array(self.mB, dtype = object)) + (1-self.beta1)*(np.array(gB, dtype = object))
    self.vB = (self.beta2 * np.array(self.vB, dtype = object)) + (1-self.beta2)*((np.array(gB, dtype = object)**2))

    # Bias Correction
    self.mW = (self.mW)*(1.0/(1-(self.beta1**self.t)))
    self.vW = (self.vW)*(1.0/(1-(self.beta2**self.t)))
    self.mB = (self.mB)*(1.0/(1-(self.beta1**self.t)))
    self.vB = (self.vB)*(1.0/(1-(self.beta2**self.t)))

    W = (1-self.lr*self.reg)*np.array(params['w'], dtype = object) - (self.lr/((self.vW + 1e-7)**0.5)) * self.mW
    self.vW = self.vW.tolist()
    self.mW = self.mW.tolist()

    B = (1-self.lr*self.reg)*np.array(params['b'], dtype = object) - (self.lr/((self.vB + 1e-7)**0.5)) * self.mB
    self.vB = self.vB.tolist()
    self.mB = self.mB.tolist()

    return W.tolist(), B.tolist()

# %% [markdown]
# ##### Training Function

# %%
def train(X_train, y_train,x_val, y_val, num_inputs_nodes, hidden_layers, num_output_nodes, init_type, epochs, batch_size, loss_type,activation_type, optimizer_name, learning_rate, reg_lamda):
  if optimizer_name=='sgd':
    optimizer = SGD()
  elif optimizer_name=='momentum':
    optimizer = Momentum()
  elif optimizer_name=='rmsprop':
    optimizer = RMSprop()
  elif optimizer_name=='nesterov':
    optimizer = Nesterov()
  elif optimizer_name=='adam':
    optimizer = Adam()    
  

  try:   
    optimizer.activation_type = activation_type
    optimizer.loss_type = loss_type
  except:
    pass

  W, B = param_inint(num_inputs_nodes,hidden_layers, num_output_nodes, init_type)
  N = X_train.shape[0]
  n_batches = int(np.floor(N/batch_size))
  optimizer.lr = learning_rate
  optimizer.reg = reg_lamda

  for epoch in range(epochs):

    train_loss = []
    train_accuracy = []
    val_loss = []
    val_accuracy = []
    l = 0
    acc = 0
    temp = 0
    for batch in range(n_batches):
      x = np.squeeze(X_train[batch*batch_size:batch_size+batch*batch_size]).T
      y = one_hot(y_train[batch*batch_size:batch_size+batch*batch_size], 10)
      y_hat, h, a = feed_forward(x, W,B, activation_type)
      gw, gb, gh, ga = back_prop(x, y,y_hat,a,h, W,B, batch_size, loss_type, activation_type)
      W,B = optimizer.update(W,B, gw,gb)
      l += loss_compute(y_train[batch*batch_size:batch_size+batch*batch_size],y_hat, loss_type, W,reg_lamda)
      acc += accuracy(y_hat, y_train[batch*batch_size:batch_size+batch*batch_size])

    if N%batch_size != 0:
        x = np.squeeze(X_train[-1*(N%batch_size):]).T
        y = one_hot(y_train[-1*(N%batch_size):], 10)
        y_hat, h, a = feed_forward(x, W,B, activation_type)
        gw, gb, gh, ga = back_prop(x, y,y_hat,a,h, W,B, N%batch_size, loss_type, activation_type)
        W,B = optimizer.update(W,B, gw,gb)
        l += loss_compute(y_train[-1*(N%batch_size):],y_hat, loss_type, W,reg_lamda)
        acc += accuracy(y_hat, y_train[-1*(N%batch_size):])
        temp = 1

    l = l/(n_batches + (N%batch_size))
    acc = acc/(n_batches + temp)

    train_loss.append(l)
    train_accuracy.append(acc)
    #print(f"Epoch:{epoch+1}")
    #print(f"Train Loss: {l}")
    #print(f"Train Accuracy: {acc}")

    #### Validation
    if x_val.any():
      y_val_hat, _,_ = feed_forward(np.squeeze(x_val).T, W,B, activation_type)
      val_acc = accuracy(y_val_hat,y_val)
      val_l = loss_compute(y_val, y_val_hat, loss_type,W = None, reg_lamda = reg_lamda)
      val_accuracy.append(val_acc)
      val_loss.append(val_l)
      #print(f"Val Loss: {val_l}")
      #print(f"Val Accuracy: {val_acc}")

    wandb.log({"epoch":epoch,"Train_loss":l,"Train_acc":acc,"val_loss":val_l,"val_Accuracy":val_acc})
  return W,B, train_loss, train_accuracy, val_loss, val_accuracy

# %%
# !pip install wandb
# !wandb login
import wandb
# Out:
# Requirement already satisfied: wandb in /usr/local/lib/python3.7/dist-packages (0.12.11)
# Requirement already satisfied: GitPython>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.1.27)
# Requirement already satisfied: pathtools in /usr/local/lib/python3.7/dist-packages (from wandb) (0.1.2)
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (5.4.8)
# Requirement already satisfied: six>=1.13.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.15.0)
# Requirement already satisfied: promise<3,>=2.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.5.6)
# Requirement already satisfied: python-dateutil>=2.6.1 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.8.2)
# Requirement already satisfied: yaspin>=1.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.1.0)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (0.4.0)
# Requirement already satisfied: setproctitle in /usr/local/lib/python3.7/dist-packages (from wandb) (1.2.2)
# Requirement already satisfied: Click!=8.0.0,>=7.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (7.1.2)
# Requirement already satisfied: PyYAML in /usr/local/lib/python3.7/dist-packages (from wandb) (3.13)
# Requirement already satisfied: protobuf>=3.12.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (3.17.3)
# Requirement already satisfied: shortuuid>=0.5.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (1.0.8)
# Requirement already satisfied: requests<3,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from wandb) (2.23.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (4.0.9)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.7/dist-packages (from GitPython>=1.0.0->wandb) (3.10.0.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.7/dist-packages (from gitdb<5,>=4.0.1->GitPython>=1.0.0->wandb) (5.0.0)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (2021.10.8)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests<3,>=2.0.0->wandb) (3.0.4)
# Requirement already satisfied: termcolor<2.0.0,>=1.1.0 in /usr/local/lib/python3.7/dist-packages (from yaspin>=1.0.0->wandb) (1.1.0)
# wandb: Currently logged in as: tejoram (use `wandb login --relogin` to force relogin)

# %%
sweep_configuration = {'method'    : "random",  #Other available--> grid, bayes
                       'metric'    : {'name': 'val_Accuracy','goal':'maximize'},
                       'parameters': {'epochs':{'values':[ 5, 10]},
                                      'hidden_layers':{'values':[[64,32],[64,32,16],[128,64,32],[128,64,32,16],[128,32,32,16]] }, #change needed
                                      'learning_rate':{'values':[1e-3,1e-4]},
                                      'weight_decay':{'values':[0, 0.0005, 0.5]},
                                      'optimizer_name': {'values':['sgd', 'momentum', 'rmsprop', 'nesterov','adam']}, #, 'nesterov','adam', 'nadam'
                                      'batch_size':{'values':[16,32,64]},
                                      'init_type': {'values':['random','xavier']},
                                      'activation_type':{'values':['sigmoid','tanh','ReLU']},
                                      'loss_type': {'values':['cross_entropy']} }}

# %%
def sweep_train():

  hyperparameters=dict(epochs = 5,
                      hidden_layers= [64,32],
                      learning_rate=1e-4,
                      weight_decay=0,
                      optimizer_name='sgd',
                      batch_size=16,
                      init_type='random',
                      activation_type='sigmoid',
                      loss_type='cross_entropy',
                      reg_lamda=0)
                           
  wandb.init(project="CS6910-Assignment-1", entity="tejoram",config=hyperparameters)
  config=wandb.config
  epochs=config.epochs
  hidden_layers=config.hidden_layers
  learning_rate=config.learning_rate
  weight_decay=config.weight_decay
  optimizer_name=config.optimizer_name
  batch_size=config.batch_size
  init_type=config.init_type
  activation_type=config.activation_type
  loss_type=config.loss_type
  reg_lamda=config.reg_lamda  
  wandb.run.name = "e_{}_hl_{}_lr_{}_wd_{}_o_{}_bs_{}_winit_{}_ac_{}_los_{}_r_{}".format(epochs,\
                                                                                    hidden_layers,\
                                                                                    learning_rate,\
                                                                                    weight_decay,\
                                                                                    optimizer_name,\
                                                                                    batch_size,\
                                                                                    init_type,\
                                                                                    activation_type,\
                                                                                    loss_type,\
                                                                                    reg_lamda)
  
  _,_,train_loss, train_accuracy, val_loss, val_accuracy = train(X_train, y_train, X_validation, y_validation, 784, hidden_layers, 10, init_type, epochs, batch_size, loss_type, activation_type, optimizer_name, learning_rate, reg_lamda)

# %%
sweep_id = wandb.sweep(sweep_configuration,project='CS6910-Assignment-1')
wandb.agent(sweep_id,function=sweep_train,project='CS6910-Assignment-1',count=100)
# Out:
# Create sweep with ID: yttmvpj4
# Sweep URL: https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4
# wandb: Agent Starting Run: fkncwkbv with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [128, 64, 32, 16]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: rmsprop
# wandb: 	weight_decay: 0.0005
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_130355-fkncwkbv</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/fkncwkbv" target="_blank">devoted-sweep-1</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▃▄▅▆▆▇▇██</td></tr><tr><td>Train_loss</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▃▄▅▅▇▇▇██</td></tr><tr><td>val_loss</td><td>█▆▅▄▃▃▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>75.06296</td></tr><tr><td>Train_loss</td><td>0.70061</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>75.5</td></tr><tr><td>val_loss</td><td>0.6917</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">devoted-sweep-1</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/fkncwkbv" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/fkncwkbv</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_130355-fkncwkbv/logs</code>
# wandb: Sweep Agent: Waiting for job.
# wandb: Job received.
# wandb: Agent Starting Run: 41wuzuv2 with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [64, 32, 16]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: adam
# wandb: 	weight_decay: 0.5
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_130734-41wuzuv2</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/41wuzuv2" target="_blank">copper-sweep-2</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:159: RuntimeWarning: overflow encountered in multiply
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:161: RuntimeWarning: overflow encountered in multiply
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁████</td></tr><tr><td>Train_loss</td><td>█▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>2.39003</td></tr><tr><td>Train_loss</td><td>2.41961</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>2.38333</td></tr><tr><td>val_loss</td><td>2.44423</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">copper-sweep-2</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/41wuzuv2" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/41wuzuv2</a><br/>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_130734-41wuzuv2/logs</code>
# wandb: Agent Starting Run: 6k71a3oo with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [128, 32, 32, 16]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: rmsprop
# wandb: 	weight_decay: 0
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_130836-6k71a3oo</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/6k71a3oo" target="_blank">graceful-sweep-3</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▆▇▇█</td></tr><tr><td>Train_loss</td><td>█▃▂▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▅▆▇█</td></tr><tr><td>val_loss</td><td>█▄▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>87.08346</td></tr><tr><td>Train_loss</td><td>0.37768</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>86.86667</td></tr><tr><td>val_loss</td><td>0.3818</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">graceful-sweep-3</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/6k71a3oo" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/6k71a3oo</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_130836-6k71a3oo/logs</code>
# wandb: Agent Starting Run: mr28zzte with config:
# wandb: 	activation_type: ReLU
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [64, 32, 16]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: adam
# wandb: 	weight_decay: 0
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_131003-mr28zzte</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/mr28zzte" target="_blank">crisp-sweep-4</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▁▁▁▁</td></tr><tr><td>Train_loss</td><td>█▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>4.79488</td></tr><tr><td>Train_loss</td><td>2.19003</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>5.13333</td></tr><tr><td>val_loss</td><td>2.30819</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">crisp-sweep-4</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/mr28zzte" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/mr28zzte</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_131003-mr28zzte/logs</code>
# wandb: Agent Starting Run: pkr0f86o with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [128, 32, 32, 16]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: sgd
# wandb: 	weight_decay: 0
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_131044-pkr0f86o</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/pkr0f86o" target="_blank">balmy-sweep-5</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>█▂▁▂▂</td></tr><tr><td>Train_loss</td><td>█▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▇███</td></tr><tr><td>val_loss</td><td>█▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>9.65084</td></tr><tr><td>Train_loss</td><td>2.18127</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>10.33333</td></tr><tr><td>val_loss</td><td>2.30256</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">balmy-sweep-5</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/pkr0f86o" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/pkr0f86o</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_131044-pkr0f86o/logs</code>
# wandb: Agent Starting Run: qkvzhwr1 with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [128, 64, 32, 16]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: rmsprop
# wandb: 	weight_decay: 0.0005
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_131130-qkvzhwr1</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/qkvzhwr1" target="_blank">efficient-sweep-6</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▆▇██</td></tr><tr><td>Train_loss</td><td>█▃▂▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▅▇▇█</td></tr><tr><td>val_loss</td><td>█▄▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>87.47963</td></tr><tr><td>Train_loss</td><td>0.37766</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>87.23333</td></tr><tr><td>val_loss</td><td>0.38389</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">efficient-sweep-6</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/qkvzhwr1" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/qkvzhwr1</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_131130-qkvzhwr1/logs</code>
# wandb: Agent Starting Run: 7k26e9zr with config:
# wandb: 	activation_type: ReLU
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [64, 32]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: sgd
# wandb: 	weight_decay: 0.5
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_131353-7k26e9zr</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/7k26e9zr" target="_blank">wise-sweep-7</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▆▇██</td></tr><tr><td>Train_loss</td><td>█▃▂▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▅▆▇█</td></tr><tr><td>val_loss</td><td>█▄▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>86.49659</td></tr><tr><td>Train_loss</td><td>0.35598</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>86.6</td></tr><tr><td>val_loss</td><td>0.37618</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">wise-sweep-7</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/7k26e9zr" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/7k26e9zr</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_131353-7k26e9zr/logs</code>
# wandb: Agent Starting Run: ryk1dngf with config:
# wandb: 	activation_type: ReLU
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [64, 32]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: rmsprop
# wandb: 	weight_decay: 0.5
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_131419-ryk1dngf</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/ryk1dngf" target="_blank">glamorous-sweep-8</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▅▆▆▇▇▇███</td></tr><tr><td>Train_loss</td><td>█▄▃▃▂▂▂▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▅▆▇▇██▇█▇</td></tr><tr><td>val_loss</td><td>█▃▂▁▁▁▁▃▃▃</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>90.54259</td></tr><tr><td>Train_loss</td><td>0.25477</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>88.01667</td></tr><tr><td>val_loss</td><td>0.35643</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">glamorous-sweep-8</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/ryk1dngf" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/ryk1dngf</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_131419-ryk1dngf/logs</code>
# wandb: Agent Starting Run: rkhedtpo with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [64, 32]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: nesterov
# wandb: 	weight_decay: 0
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_131617-rkhedtpo</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/rkhedtpo" target="_blank">stoic-sweep-9</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">stoic-sweep-9</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/rkhedtpo" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/rkhedtpo</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_131617-rkhedtpo/logs</code>
# Run rkhedtpo errored: NameError("name 'x' is not defined")
# wandb: ERROR Run rkhedtpo errored: NameError("name 'x' is not defined")
# wandb: Agent Starting Run: 0s4lhnhd with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [64, 32, 16]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: adam
# wandb: 	weight_decay: 0.0005
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_131632-0s4lhnhd</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/0s4lhnhd" target="_blank">gallant-sweep-10</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Train_loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>8.40556</td></tr><tr><td>Train_loss</td><td>2.31483</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>8.83333</td></tr><tr><td>val_loss</td><td>2.31355</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">gallant-sweep-10</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/0s4lhnhd" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/0s4lhnhd</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_131632-0s4lhnhd/logs</code>
# wandb: Agent Starting Run: c434gj6s with config:
# wandb: 	activation_type: ReLU
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [128, 64, 32]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: sgd
# wandb: 	weight_decay: 0.0005
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_131947-c434gj6s</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/c434gj6s" target="_blank">daily-sweep-11</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▅▆▆▇▇▇███</td></tr><tr><td>Train_loss</td><td>█▄▃▃▂▂▂▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▅▆▇▇█████</td></tr><tr><td>val_loss</td><td>█▄▃▂▂▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>89.79191</td></tr><tr><td>Train_loss</td><td>0.26391</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>87.65</td></tr><tr><td>val_loss</td><td>0.3398</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">daily-sweep-11</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/c434gj6s" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/c434gj6s</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_131947-c434gj6s/logs</code>
# wandb: Agent Starting Run: 3z9l53bv with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 64
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [64, 32]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: momentum
# wandb: 	weight_decay: 0.5
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_132053-3z9l53bv</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/3z9l53bv" target="_blank">gentle-sweep-12</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▅▇██</td></tr><tr><td>Train_loss</td><td>█▄▂▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▅▇▇█</td></tr><tr><td>val_loss</td><td>█▄▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>77.68809</td></tr><tr><td>Train_loss</td><td>0.588</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>78.26667</td></tr><tr><td>val_loss</td><td>0.59189</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">gentle-sweep-12</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/3z9l53bv" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/3z9l53bv</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_132053-3z9l53bv/logs</code>
# wandb: Agent Starting Run: m556fqf2 with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [64, 32]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: adam
# wandb: 	weight_decay: 0.0005
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_132130-m556fqf2</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/m556fqf2" target="_blank">vocal-sweep-13</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁█████████</td></tr><tr><td>Train_loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>25.49985</td></tr><tr><td>Train_loss</td><td>2.09894</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>25.28333</td></tr><tr><td>val_loss</td><td>2.22006</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">vocal-sweep-13</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/m556fqf2" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/m556fqf2</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_132130-m556fqf2/logs</code>
# wandb: Agent Starting Run: btvw79hr with config:
# wandb: 	activation_type: ReLU
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [64, 32, 16]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: momentum
# wandb: 	weight_decay: 0
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_132256-btvw79hr</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/btvw79hr" target="_blank">noble-sweep-14</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▆▇██</td></tr><tr><td>Train_loss</td><td>█▃▂▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▅▇██</td></tr><tr><td>val_loss</td><td>█▄▂▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>86.35404</td></tr><tr><td>Train_loss</td><td>0.37721</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>85.91667</td></tr><tr><td>val_loss</td><td>0.38641</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">noble-sweep-14</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/btvw79hr" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/btvw79hr</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_132256-btvw79hr/logs</code>
# wandb: Agent Starting Run: zq217k2m with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 64
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [64, 32, 16]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: sgd
# wandb: 	weight_decay: 0.5
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_132343-zq217k2m</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/zq217k2m" target="_blank">eternal-sweep-15</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▅▆▆▇▇▇███</td></tr><tr><td>Train_loss</td><td>█▄▃▂▂▂▂▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▅▆▇▇▇████</td></tr><tr><td>val_loss</td><td>█▄▃▃▂▂▂▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>89.2501</td></tr><tr><td>Train_loss</td><td>0.28267</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>87.56667</td></tr><tr><td>val_loss</td><td>0.34114</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">eternal-sweep-15</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/zq217k2m" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/zq217k2m</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_132343-zq217k2m/logs</code>
# wandb: Agent Starting Run: rcjns814 with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [128, 64, 32, 16]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: rmsprop
# wandb: 	weight_decay: 0
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_132455-rcjns814</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/rcjns814" target="_blank">robust-sweep-16</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▃▄▅▅▆▇▇██</td></tr><tr><td>Train_loss</td><td>█▆▅▄▃▃▂▂▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▁▃▄▅▆▇▇██</td></tr><tr><td>val_loss</td><td>█▆▅▄▄▃▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>78.77851</td></tr><tr><td>Train_loss</td><td>0.71468</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>78.9</td></tr><tr><td>val_loss</td><td>0.69929</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">robust-sweep-16</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/rcjns814" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/rcjns814</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_132455-rcjns814/logs</code>
# wandb: Agent Starting Run: dw3u3c42 with config:
# wandb: 	activation_type: ReLU
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [64, 32]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: nesterov
# wandb: 	weight_decay: 0
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_132744-dw3u3c42</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/dw3u3c42" target="_blank">cosmic-sweep-17</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">cosmic-sweep-17</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/dw3u3c42" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/dw3u3c42</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_132744-dw3u3c42/logs</code>
# Run dw3u3c42 errored: NameError("name 'x' is not defined")
# wandb: ERROR Run dw3u3c42 errored: NameError("name 'x' is not defined")
# wandb: Agent Starting Run: 4734352a with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [128, 64, 32]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: nesterov
# wandb: 	weight_decay: 0.0005
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_132759-4734352a</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/4734352a" target="_blank">dry-sweep-18</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">dry-sweep-18</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/4734352a" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/4734352a</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_132759-4734352a/logs</code>
# Run 4734352a errored: NameError("name 'x' is not defined")
# wandb: ERROR Run 4734352a errored: NameError("name 'x' is not defined")
# wandb: Agent Starting Run: 1r42to8i with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [128, 64, 32]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: adam
# wandb: 	weight_decay: 0
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_132820-1r42to8i</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/1r42to8i" target="_blank">iconic-sweep-19</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁█████████</td></tr><tr><td>Train_loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>12.72593</td></tr><tr><td>Train_loss</td><td>2.63955</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>12.91667</td></tr><tr><td>val_loss</td><td>2.64681</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">iconic-sweep-19</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/1r42to8i" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/1r42to8i</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_132820-1r42to8i/logs</code>
# wandb: Agent Starting Run: t1hr12dr with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [128, 64, 32, 16]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: adam
# wandb: 	weight_decay: 0.5
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_133347-t1hr12dr</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/t1hr12dr" target="_blank">playful-sweep-20</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▁▁▁▁</td></tr><tr><td>Train_loss</td><td>█▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>10.01852</td></tr><tr><td>Train_loss</td><td>2.31296</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>9.83333</td></tr><tr><td>val_loss</td><td>2.31476</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">playful-sweep-20</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/t1hr12dr" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/t1hr12dr</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_133347-t1hr12dr/logs</code>
# ...
# Waiting for W&B process to finish... <strong style="color:red">(failed 1).</strong> Press Control-C to abort syncing.
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# Synced <strong style="color:#cdcd00">sandy-sweep-94</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/lctnlgfp" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/lctnlgfp</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_151431-lctnlgfp/logs</code>
# Run lctnlgfp errored: NameError("name 'x' is not defined")
# wandb: ERROR Run lctnlgfp errored: NameError("name 'x' is not defined")
# wandb: Agent Starting Run: kwzzwnph with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 16
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [64, 32]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: rmsprop
# wandb: 	weight_decay: 0.0005
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_151451-kwzzwnph</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/kwzzwnph" target="_blank">likely-sweep-95</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▄▆▆▇▇▇███</td></tr><tr><td>Train_loss</td><td>█▄▃▃▂▂▂▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▄▅▇▆▇████</td></tr><tr><td>val_loss</td><td>█▅▄▂▃▂▁▁▁▂</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>90.37407</td></tr><tr><td>Train_loss</td><td>0.2632</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>87.88333</td></tr><tr><td>val_loss</td><td>0.34966</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">likely-sweep-95</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/kwzzwnph" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/kwzzwnph</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_151451-kwzzwnph/logs</code>
# wandb: Agent Starting Run: mqs1u2ji with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [128, 64, 32, 16]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: adam
# wandb: 	weight_decay: 0.0005
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_151719-mqs1u2ji</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/mqs1u2ji" target="_blank">lunar-sweep-96</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>Train_loss</td><td>█▁▁▁▁▁▁▁▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>val_loss</td><td>▁▁▁▁▁▁▁▁▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>9.95816</td></tr><tr><td>Train_loss</td><td>2.29288</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>10.35</td></tr><tr><td>val_loss</td><td>2.31074</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">lunar-sweep-96</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/mqs1u2ji" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/mqs1u2ji</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_151719-mqs1u2ji/logs</code>
# wandb: Agent Starting Run: g6aeyxs3 with config:
# wandb: 	activation_type: ReLU
# wandb: 	batch_size: 32
# wandb: 	epochs: 10
# wandb: 	hidden_layers: [128, 64, 32, 16]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: momentum
# wandb: 	weight_decay: 0.5
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_152014-g6aeyxs3</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/g6aeyxs3" target="_blank">vivid-sweep-97</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▅▆▇▇▇█▇██</td></tr><tr><td>Train_loss</td><td>█▄▃▂▂▂▂▂▁▁</td></tr><tr><td>epoch</td><td>▁▂▃▃▄▅▆▆▇█</td></tr><tr><td>val_Accuracy</td><td>▁▃▅▅▄▆▆▇█▇</td></tr><tr><td>val_loss</td><td>█▇▃▃▇▃▃▃▁▄</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>88.40344</td></tr><tr><td>Train_loss</td><td>0.32271</td></tr><tr><td>epoch</td><td>9</td></tr><tr><td>val_Accuracy</td><td>86.98333</td></tr><tr><td>val_loss</td><td>0.40859</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">vivid-sweep-97</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/g6aeyxs3" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/g6aeyxs3</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_152014-g6aeyxs3/logs</code>
# wandb: Agent Starting Run: 10yjfpnh with config:
# wandb: 	activation_type: ReLU
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [64, 32, 16]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.0001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: rmsprop
# wandb: 	weight_decay: 0.0005
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_152156-10yjfpnh</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/10yjfpnh" target="_blank">deft-sweep-98</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▆▇██</td></tr><tr><td>Train_loss</td><td>█▃▂▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▄▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>84.86374</td></tr><tr><td>Train_loss</td><td>0.43495</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>85.05</td></tr><tr><td>val_loss</td><td>0.43526</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">deft-sweep-98</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/10yjfpnh" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/10yjfpnh</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_152156-10yjfpnh/logs</code>
# wandb: Agent Starting Run: 2pfy7lrx with config:
# wandb: 	activation_type: tanh
# wandb: 	batch_size: 32
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [64, 32, 16]
# wandb: 	init_type: xavier
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: sgd
# wandb: 	weight_decay: 0
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_152247-2pfy7lrx</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/2pfy7lrx" target="_blank">lyric-sweep-99</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▆▇██</td></tr><tr><td>Train_loss</td><td>█▃▂▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▄▆██</td></tr><tr><td>val_loss</td><td>█▅▃▂▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>87.45927</td></tr><tr><td>Train_loss</td><td>0.34753</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>86.96667</td></tr><tr><td>val_loss</td><td>0.36325</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">lyric-sweep-99</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/2pfy7lrx" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/2pfy7lrx</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_152247-2pfy7lrx/logs</code>
# wandb: Agent Starting Run: sbg4d8yq with config:
# wandb: 	activation_type: sigmoid
# wandb: 	batch_size: 16
# wandb: 	epochs: 5
# wandb: 	hidden_layers: [64, 32, 16]
# wandb: 	init_type: random
# wandb: 	learning_rate: 0.001
# wandb: 	loss_type: cross_entropy
# wandb: 	optimizer_name: momentum
# wandb: 	weight_decay: 0.0005
# wandb: WARNING Ignored wandb.init() arg project when running a sweep.
# wandb: WARNING Ignored wandb.init() arg entity when running a sweep.
# Tracking run with wandb version 0.12.11
# Run data is saved locally in <code>/content/wandb/run-20220302_152338-sbg4d8yq</code>
# Syncing run <strong><a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/sbg4d8yq" target="_blank">fresh-sweep-100</a></strong> to <a href="https://wandb.ai/tejoram/CS6910-Assignment-1" target="_blank">Weights & Biases</a> (<a href="https://wandb.me/run" target="_blank">docs</a>)<br/>Sweep page:  <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/sweeps/yttmvpj4</a>
# Waiting for W&B process to finish... <strong style="color:green">(success).</strong>
# VBox(children=(Label(value='0.001 MB of 0.001 MB uploaded (0.000 MB deduped)\r'), FloatProgress(value=1.0, max…
# <style>
#     table.wandb td:nth-child(1) { padding: 0 10px; text-align: right }
#     .wandb-row { display: flex; flex-direction: row; flex-wrap: wrap; width: 100% }
#     .wandb-col { display: flex; flex-direction: column; flex-basis: 100%; flex: 1; padding: 10px; }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>▁▆▇██</td></tr><tr><td>Train_loss</td><td>█▃▂▁▁</td></tr><tr><td>epoch</td><td>▁▃▅▆█</td></tr><tr><td>val_Accuracy</td><td>▁▆▇██</td></tr><tr><td>val_loss</td><td>█▄▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>Train_acc</td><td>85.48333</td></tr><tr><td>Train_loss</td><td>0.4141</td></tr><tr><td>epoch</td><td>4</td></tr><tr><td>val_Accuracy</td><td>85.51667</td></tr><tr><td>val_loss</td><td>0.40692</td></tr></table><br/></div></div>
# Synced <strong style="color:#cdcd00">fresh-sweep-100</strong>: <a href="https://wandb.ai/tejoram/CS6910-Assignment-1/runs/sbg4d8yq" target="_blank">https://wandb.ai/tejoram/CS6910-Assignment-1/runs/sbg4d8yq</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20220302_152338-sbg4d8yq/logs</code>
